# %%
import pandas as pd
from sqlalchemy import create_engine
from pandas_profiling import ProfileReport
from pandasgui import show

# %%
engine = create_engine('mysql+pymysql://root:123456@localhost:3306/stockdata')
#转成十进制显示，不成功
#pd.set_option('display.float_format', '{:.2g}'.format)
#pd.Series(data=[0.00000001])
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
sql_query = 'select * from stockinfobase;'

# %%
sql_query = 'select * from stockinfobase;'
df_read = pd.read_sql_query(sql_query, engine)
df_read["ts_code"] = df_read["ts_code"].apply(lambda x:x[0:6])
df_read
# Out:
#      ts_code  symbol     name  area industry list_date composition
# 0     000001  000001     平安银行    深圳       银行  19910403        None
# 1     000002  000002      万科A    深圳     全国地产  19910129        None
# 2     000004  000004     国华网安    深圳     软件服务  19910114        None
# 3     000005  000005     ST星源    深圳     环境保护  19901210        None
# 4     000006  000006     深振业A    深圳     区域地产  19920427      zz1000
# ...      ...     ...      ...   ...      ...       ...         ...
# 4688  871553  871553     凯腾精工  None     None  20210806        None
# 4689  871642  871642     通易航天  None     None  20210816        None
# 4690  871981  871981     晶赛科技  None     None  20211115        None
# 4691  872925  872925     锦好医疗  None     None  20211025        None
# 4692  689009  689009  九号公司-WD    北京      摩托车  20201029        kc50
#
# [4693 rows x 7 columns]

# %%
sql_query = 'select compositiontype,security_name_abbr,secucode from stockcomposition order by compositiontype;'
# 使用pandas的read_sql_query函数执行SQL语句，并存入DataFrame
df_read = pd.read_sql_query(sql_query, engine)
print(df_read)
# Out:
#     compositiontype security_name_abbr   secucode
# 0             hs300               国电南瑞  600406.SH
# 1             hs300               华鲁恒升  600426.SH
# 2             hs300                片仔癀  600436.SH
# 3             hs300               通威股份  600438.SH
# 4             hs300               中国动力  600482.SH
# ..              ...                ...        ...
# 894           zz500               南微医学  688029.SH
# 895           zz500               虹软科技  688088.SH
# 896           zz500               晶晨股份  688099.SH
# 897           zz500               道通科技  688208.SH
# 898           zz500               微芯生物  688321.SH
#
# [899 rows x 3 columns]

# %%
sql_query = 'select ts_code,full_value,limit_value from stockvaluebase order by full_value desc ;'
df_read_marketvalue = pd.read_sql_query(sql_query, engine)
sql_query = "select substring(ts_code,1,6)as ts_code from stocktradedailyinfo where trade_date = '20211022';"
df_read_info = pd.read_sql_query(sql_query, engine)

# %%
print(df_read_marketvalue.shape[0])
print(df_read_info)
# Out:
# 4312
#      ts_code
# 0     000001
# 1     000002
# 2     000004
# 3     000005
# 4     000006
# ...      ...
# 4499  688799
# 4500  688800
# 4501  688819
# 4502  688981
# 4503  689009
#
# [4504 rows x 1 columns]

# %%
df_differ = df_read_marketvalue.loc[~df_read_marketvalue.ts_code.isin(df_read_info.ts_code)]

# %% [markdown]
# pandas.set_option('display.max_rows', df_differ.shape[0]+1)
# 设置显示的最大行数

# %%
pd.set_option('display.max_rows', df_differ.shape[0]+1)
# 4275  833873    1038430003.540   508165529.060
# 4277  834475    1021363200.000   282080160.000
# 4278  836263    1016109600.000   460371120.000
# 4283  830839     963600000.000   238840305.000
# 4284  838030     962157483.780   469640934.520
# 4285  871245     943800000.000   198645816.160
# 4287  872925     942354000.000   286829192.650
# 4288  838275     934418408.000   263779516.000
# 4289  838163     932400000.000   243842950.000
# 4293  836260     868784500.000   269412011.540
# 4294  838924     864030000.000   393417926.280
# 4295  833427     833832360.000   208888776.000
# 4296  834415     778016226.550   444034076.300
# 4298  871553     771617770.200   336125843.790
# 4299  832145     718904500.000   251387300.000
# 4300  832000     712036894.000   263030110.000
# 4301  839946     696550685.880   286493968.920
# 4302  832225     694799591.640   353183143.600
# 4303  837242     681736890.000   261519924.000
# 4305  831856     628294262.390   410083358.390
# 4306  871396     627448635.980   310391490.940
# 4307  834765     600760569.720   176558693.190
# 4308  836149     587113680.000   317199584.240
# 4309  835508     573500000.000   298650125.000

# %%
result0=pd.merge(df_read_marketvalue,df_read_info,on=['ts_code'])

# %%
print(result0)
# Out:
#      ts_code        full_value       limit_value
# 0     600519 2374992684636.000 2374992684636.000
# 1     601398 1696493783743.640 1283354131685.640
# 2     601939 1552568170188.060   59576613733.260
# 3     600036 1266540646082.220 1035985589224.380
# 4     300750 1228358582400.000 1074371980770.000
# ...      ...               ...               ...
# 4154  600890     891960184.500     891960184.500
# 4155  603157     772217015.220     468970268.070
# 4156  600091     647370535.520     647370535.520
# 4157  000835     421520882.460     390734550.000
# 4158  603996     399199500.000     399199500.000
#
# [4159 rows x 3 columns]

# %% [markdown]
# 上面是按市值、或者流动市值排序的表

# %%
query_code_gainian = "select f12 as ts_code,f14,gainianpojo_f12 as f12 from gainianeachpojo "
query_gainian = "select f12,f14 from gainianpojo"
result1 = pd.read_sql_query(query_code_gainian, engine)
result2 = pd.read_sql_query(query_gainian, engine)

result = pd.merge(result1,result2,on=['f12'])
print(result)
# Out:
#       ts_code f14_x     f12 f14_y
# 0      002182  云海金属  BK0490    军工
# 1      002497  雅化集团  BK0490    军工
# 2      300047  天源迪科  BK0490    军工
# 3      002756  永兴材料  BK0490    军工
# 4      000932  华菱钢铁  BK0490    军工
# ...       ...   ...     ...   ...
# 20984  002624  完美世界  BK0853  电子竞技
# 20985  300043  星辉娱乐  BK0853  电子竞技
# 20986  300144  宋城演艺  BK0853  电子竞技
# 20987  300052   中青宝  BK0853  电子竞技
# 20988  300315  掌趣科技  BK0853  电子竞技
#
# [20989 rows x 4 columns]

# %%
result.type
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\Public\Documents\Wondershare\CreatorTemp/ipykernel_8828/541535286.py in <module>
# ----> 1 result.type
#
# d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'type'

# %%
result['f14_y'] = result.groupby(['ts_code'])['f14_y'].transform(lambda x: '，'.join(x))

# %% [raw]
# pandas的操作很多时候要注意带原有的引用，
# result['f14_y'] = result.groupby(['code_f12'])['f14_y'].transform(lambda x: '，'.join(x))
# 像这里的result['f14_y'] = 左操作
# result.drop_duplicates(subset=None, keep="first", inplace=True)
# 以及

# %%
result.drop('f12',axis=1,inplace=True)
result.drop_duplicates(subset=None, keep="first", inplace=True)
show(result)
# Out:
# PandasGUI INFO — pandasgui.gui — Opening PandasGUI
# PandasGUI ERROR — pandasgui.store — invalid syntax (<unknown>, line 1)
# Traceback (most recent call last):
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandasgui\store.py", line 594, in apply_filters
#     df = df.query(filt.expr)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\frame.py", line 4060, in query
#     res = self.eval(expr, **kwargs)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\frame.py", line 4191, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\eval.py", line 348, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\expr.py", line 806, in __init__
#     self.terms = self.parse()
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\expr.py", line 825, in parse
#     return self._visitor.visit(self.expr)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\expr.py", line 407, in visit
#     raise e
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\expr.py", line 403, in visit
#     node = ast.fix_missing_locations(ast.parse(clean))
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
#   File "<unknown>", line 1
#     ts_code ==000 333
#                   ^
# SyntaxError: invalid syntax
# PandasGUI ERROR — pandasgui.store — invalid syntax (<unknown>, line 1)
# Traceback (most recent call last):
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandasgui\store.py", line 594, in apply_filters
#     df = df.query(filt.expr)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\frame.py", line 4060, in query
#     res = self.eval(expr, **kwargs)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\frame.py", line 4191, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\eval.py", line 348, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\expr.py", line 806, in __init__
#     self.terms = self.parse()
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\expr.py", line 825, in parse
#     return self._visitor.visit(self.expr)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\expr.py", line 407, in visit
#     raise e
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\expr.py", line 403, in visit
#     node = ast.fix_missing_locations(ast.parse(clean))
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\ast.py", line 50, in parse
#     return compile(source, filename, mode, flags,
#   File "<unknown>", line 1
#     ts_code =000 333
#                  ^
# SyntaxError: invalid syntax
# PandasGUI ERROR — pandasgui.store — cannot assign without a target object
# Traceback (most recent call last):
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandasgui\store.py", line 594, in apply_filters
#     df = df.query(filt.expr)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\frame.py", line 4060, in query
#     res = self.eval(expr, **kwargs)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\frame.py", line 4191, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\eval.py", line 348, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\expr.py", line 806, in __init__
#     self.terms = self.parse()
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\expr.py", line 825, in parse
#     return self._visitor.visit(self.expr)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\expr.py", line 411, in visit
#     return visitor(node, **kwargs)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\expr.py", line 417, in visit_Module
#     return self.visit(expr, **kwargs)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\expr.py", line 411, in visit
#     return visitor(node, **kwargs)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\expr.py", line 619, in visit_Assign
#     raise ValueError("cannot assign without a target object")
# ValueError: cannot assign without a target object
# PandasGUI ERROR — pandasgui.store — cannot assign without a target object
# Traceback (most recent call last):
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandasgui\store.py", line 594, in apply_filters
#     df = df.query(filt.expr)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\frame.py", line 4060, in query
#     res = self.eval(expr, **kwargs)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\frame.py", line 4191, in eval
#     return _eval(expr, inplace=inplace, **kwargs)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\eval.py", line 348, in eval
#     parsed_expr = Expr(expr, engine=engine, parser=parser, env=env)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\expr.py", line 806, in __init__
#     self.terms = self.parse()
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\expr.py", line 825, in parse
#     return self._visitor.visit(self.expr)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\expr.py", line 411, in visit
#     return visitor(node, **kwargs)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\expr.py", line 417, in visit_Module
#     return self.visit(expr, **kwargs)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\expr.py", line 411, in visit
#     return visitor(node, **kwargs)
#   File "d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\computation\expr.py", line 619, in visit_Assign
#     raise ValueError("cannot assign without a target object")
# ValueError: cannot assign without a target object
# d:\ProgramData\Anaconda3\envs\pytorch3.9\lib\site-packages\pandas\core\apply.py:507: FutureWarning:
#
# Dropping invalid columns in DataFrameGroupBy.mean is deprecated. In a future version, a TypeError will be raised. Before calling .mean, select only columns which should be valid for the function.

# %% [markdown]
# result['f12'] = result.groupby(['code_f12'])['f12'].transform(lambda x: '，'.join(x))
# result['f14_y'] = result.groupby(['code_f12'])['f14_y'].transform(lambda x: '，'.join(x))

# %% [markdown]
# 准备拼接基础表A、基础表B

# %%
print(list(result))
# Out:
# ['ts_code', 'f14_x', 'f14_y']

# %%
target_df = pd.merge(result0,result[["ts_code","f14_y"]],on=['ts_code'])

# %% [markdown]
# target_df.loc(target_df['ts_code']=='600308')
# 这里会报错TypeError: unhashable type: 'Series'
# loc是内置函数？
# target_df.loc[target_df['ts_code']=='600308']

# %% [markdown]
# target_df.loc[target_df['ts_code']=='600308']
# 通过指定列值，获取行值

# %%
profile = ProfileReport(target_df, title="Pandas Profiling Report",explorative=True)

# %%
profile
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]

# %%
profile.to_widgets()

# %%
target_df.loc[target_df['ts_code']=='000858']
