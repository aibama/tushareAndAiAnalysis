# %%
import pandas as pd
from sqlalchemy import create_engine
from pandas_profiling import ProfileReport

# %%
engine = create_engine('mysql+pymysql://root:123456@localhost:3306/stockdata')
#转成十进制显示，不成功
#pd.set_option('display.float_format', '{:.2g}'.format)
#pd.Series(data=[0.00000001])
pd.set_option('display.float_format', lambda x: '%.3f' % x)

# %%
query_sql = "SELECT * FROM stockdata.stockcomposition;"
result = pd.read_sql_query(query_sql, engine)
result.drop_duplicates(subset=None, keep="first", inplace=True)

# %%
result
# Out:
#         id    BPS  CLOSE_PRICE   EPS  FREE_CAP  FREE_SHARES INDUSTRY REGION  \
# 0    30963 15.830       19.080 0.800  3702.620      194.060       金融    深圳市
# 1    30962 19.100       19.020 0.950  1848.280       97.180      房地产    深圳市
# 2    31462  2.910       20.480 0.260   522.530       25.510       综合    深圳市
# 3    31461  3.670       10.620 0.440   207.820       19.570       建材    深圳市
# 4    31460  5.860       15.500 0.180   227.960       14.710     信息技术    深圳市
# ..     ...    ...          ...   ...       ...          ...      ...    ...
# 894  30568 47.270      265.600 1.580    63.740        0.240     电子设备    上海市
# 895  30567  8.290       95.610 0.430    41.840        0.440     信息技术    杭州市
# 896  30566 11.900       43.920 0.710    46.650        1.060     有色金属    湖州市
# 897  30565 11.950       55.110 0.660  1031.130       18.710     电子设备     境外
# 898  30564  5.510       81.000 0.370    49.050        0.610     机械设备     境外
#
#        ROE   SECUCODE  SECURITY_CODE SECURITY_NAME_ABBR  TOTAL_SHARES  WEIGHT  \
# 0    4.740  000001.SZ          1.000               平安银行       194.060   0.950
# 1    4.950  000002.SZ          2.000                万科A       116.250   0.670
# 2    9.430  000009.SZ          9.000               中国宝安        25.790   0.820
# 3   12.600  000012.SZ         12.000                南玻A        30.710   0.230
# 4    3.270  000021.SZ         21.000                深科技        15.610   0.220
# ..     ...        ...            ...                ...           ...     ...
# 894  3.390  688608.SH     688608.000               恒玄科技         1.200   0.940
# 895  5.230  688777.SH     688777.000               中控技术         4.940   0.560
# 896  7.340  688819.SH     688819.000               天能股份         9.720   0.710
# 897  5.170  688981.SH     688981.000               中芯国际        79.030   9.390
# 898  6.580  689009.SH     689009.000               九号公司         7.050   0.710
#
#     compositiontype         update_time
# 0             hs300 2021-09-16 23:40:02
# 1             hs300 2021-09-16 23:40:02
# 2             zz500 2021-09-16 23:40:58
# 3             zz500 2021-09-16 23:40:58
# 4             zz500 2021-09-16 23:40:58
# ..              ...                 ...
# 894            kc50 2021-09-16 23:39:23
# 895            kc50 2021-09-16 23:39:23
# 896            kc50 2021-09-16 23:39:23
# 897            kc50 2021-09-16 23:39:23
# 898            kc50 2021-09-16 23:39:23
#
# [899 rows x 16 columns]
